# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import klib
# Out:
# c:\Users\Shiva Periaswamy\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv('C:/Users/Shiva Periaswamy/Documents/project/guvi/airbnb_project/new_extraction.csv')
df
# Out:
#             id                                               name   host_id  \
# 0      1003530                New York City - Upper West Side Apt    454250
# 1     10133554                Double and triple rooms Blue mosque  52004703
# 2     10059872                 Soho Cozy, Spacious and Convenient  51624384
# 3     10084023                  City center private room with bed  51744313
# 4     10091713   Surry Hills Studio - Your Perfect Base in Sydney  13764143
# ...        ...                                                ...       ...
# 5550   9985696                                    Kadıköy-Altıyol  51303748
# 5551   9993190  Just Steps from the Ocean at Premier Platinum ...  51013381
# 5552   9887054                Quarry Bay fully furnished studio C  31386255
# 5553   9907907                         Large double room in Bondi  47615848
# 5554   9936016                        Alugo Apartamento na Tijuca  47092481
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        5555 non-null   int64
#  1   name                      5547 non-null   object
#  2   host_id                   5555 non-null   int64
#  3   host_name                 5555 non-null   object
#  4   neighbourhood             3632 non-null   object
#  5   lattitude                 5555 non-null   float64
#  6   lognitute                 5555 non-null   float64
#  7   neighbourhood_group       4668 non-null   object
#  8   room_type                 5555 non-null   object
#  9   price                     5555 non-null   int64
#  10  weekly_price              5555 non-null   int64
#  11  monthly_price             5555 non-null   int64
#  12  minimum_nights            5555 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'lattitude',
#        'lognitute', 'neighbourhood_group', 'room_type', 'price',
#        'weekly_price', 'monthly_price', 'minimum_nights', 'amenities',
#        'country', 'state', 'review_rating_percentage',
#        'review_score_cleaniness', 'review_score_location'],
#       dtype='object')

# %%
sns.catplot(x='room_type', kind="count", hue="state", data=df).set(title='Room type distrubution over each state')
plt.show()

# %%
sns.catplot(x= 'room_type', kind="count", hue="price", data=df).set(title='price distrubution over each room type')
plt.show()

# %%
df.describe()
# Out:
#                  id       host_id    lattitude    lognitute         price  \
# count  5.555000e+03  5.555000e+03  5555.000000  5555.000000   5555.000000
# mean   1.664386e+07  6.512138e+07    -6.623240    22.061230    278.766157
# std    9.622558e+06  6.816258e+07    90.525974    28.092112    842.215531
# min    1.170800e+04  2.787000e+03  -159.678690   -34.088290      9.000000
# 25%    8.376039e+06  1.024978e+07   -73.599530    20.724390     70.000000
# 50%    1.711345e+07  3.725685e+07    -8.611420    40.727130    129.000000
# 75%    2.461229e+07  1.046962e+08    29.019605    41.162755    280.000000
# max    3.295874e+07  2.477517e+08   151.338980    45.665630  48842.000000
#
#        weekly_price  monthly_price  minimum_nights  review_rating_percentage  \
# count    714.000000     656.000000     5555.000000               4082.000000
# mean    1530.903361    5391.370427        5.564356                 93.098236
# ...

# %%
df.isnull().sum()
# Out:
# id                             0
# name                           8
# host_id                        0
# host_name                      0
# neighbourhood               1923
# lattitude                      0
# lognitute                      0
# neighbourhood_group          887
# room_type                      0
# price                          0
# weekly_price                   0
# monthly_price                  0
# minimum_nights                 0
# amenities                      0
# country                        0
# state                          6
# review_rating_percentage       0
# review_score_cleaniness        0
# review_score_location          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.state.value_counts()
# Out:
# state
# Istanbul                 660
# Montreal                 648
# Barcelona                632
# Hong Kong                619
# Sydney                   609
# New York                 607
# Rio De Janeiro           603
# Porto                    554
# Oahu                     253
# Maui                     153
# The Big Island           139
# Kauai                     67
# Other (International)      4
# Other (Domestic)           1
# Name: count, dtype: int64

# %%
pd.DataFrame(df.neighbourhood.value_counts())
# Out:
#                    count
# neighbourhood
# Copacabana           124
# Le Plateau           123
# Mong Kok              90
# Waikiki               76
# Downtown Montreal     74
# ...                  ...
# Campsie                1
# Flatlands              1
# Canterbury             1
# Wolli Creek            1
# Rio Comprido           1
#
# [446 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'lattitude',
#        'lognitute', 'neighbourhood_group', 'room_type', 'price',
#        'weekly_price', 'monthly_price', 'minimum_nights', 'amenities',
#        'country', 'state', 'review_rating_percentage',
#        'review_score_cleaniness', 'review_score_location'],
#       dtype='object')

# %%
sns.boxplot(df['price'])
# Out:
# <AxesSubplot:ylabel='price'>

# %%
df[df['price'] == df['price'].median()]
# Out:
#             id                                               name    host_id  \
# 113    1047087                                  The Garden Studio    3251237
# 500   13153996               Porto Beach Apartment T2 com garagem   73408524
# 742   14004632  Stylish, spacious, central, shared rooftop ter...    5878688
# 1121  15988739    Coconut Beach. Kapaa Condo 1BD 1BA Full Kitchen   75440219
# 1129  16066381                Kapaa Sands 17 Ocean View Apartment   71362662
# 1180  16221015            Harbour, ocean, and city skyline views!   43575947
# 1222  16635022     Private 1 bedroom apartment in Redfern, Sydney   10281778
# 1470  17613188      Whole apartment,w/balconies. Close to airport  119732473
# 1504  18130053                               Super clean and cosy   21122092
# 1628  19197922       1 Bed Apartment with oceans views near Manly   52243859
# 1634   1944996    Light Filled Warehouse Apartment in Surry Hills    8740629
# ...

# %%
df.loc[ (df.room_type=='Entire home/apt') & (df.review_rating_percentage==0),'review_rating_percentage']=df.loc[ (df.room_type=='Entire home/apt') & (df.review_rating_percentage!=0),'review_rating_percentage'].median()
df.loc[ (df.room_type=='Private room') & (df.review_rating_percentage==0),'review_rating_percentage']=df.loc[ (df.room_type=='Private room') & (df.review_rating_percentage!=0),'review_rating_percentage'].median()
df.loc[ (df.room_type=='Shared room') & (df.review_rating_percentage==0),'review_rating_percentage']=df.loc[ (df.room_type=='Shared room') & (df.review_rating_percentage!=0),'review_rating_percentage'].median()

# %%
klib.cat_plot(df)
# Out:
# c:\Users\Shiva Periaswamy\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 21934 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\Shiva Periaswamy\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\Shiva Periaswamy\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 22871 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\Shiva Periaswamy\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 25151 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\Shiva Periaswamy\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 29544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
df['host_name'].value_counts().reset_index().head(10)
# Out:
#   host_name  count
# 0     Maria     37
# 1     David     26
# 2       Ana     21
# 3     Sarah     20
# 4       Jov     18
# 5      Mark     17
# 6    Daniel     17
# 7      Mike     17
# 8     Jorge     17
# 9    Carlos     17

# %%
pd.value_counts(df['neighbourhood'])[:10].plot.bar()
plt.title("Top neighbourhoods with highest number of listings")
# Out:
# Text(0.5, 1.0, 'Top neighbourhoods with highest number of listings')

# %%
klib.corr_plot(df)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
ttn = df[(df['state'] != 'Other(Domestic)') & (df['price'] != 0)]

# %%
ttn
# Out:
#             id                                               name   host_id  \
# 0      1003530                New York City - Upper West Side Apt    454250
# 1     10133554                Double and triple rooms Blue mosque  52004703
# 2     10059872                 Soho Cozy, Spacious and Convenient  51624384
# 3     10084023                  City center private room with bed  51744313
# 4     10091713   Surry Hills Studio - Your Perfect Base in Sydney  13764143
# ...        ...                                                ...       ...
# 5550   9985696                                    Kadıköy-Altıyol  51303748
# 5551   9993190  Just Steps from the Ocean at Premier Platinum ...  51013381
# 5552   9887054                Quarry Bay fully furnished studio C  31386255
# 5553   9907907                         Large double room in Bondi  47615848
# 5554   9936016                        Alugo Apartamento na Tijuca  47092481
#
# ...

# %%
tc = df.groupby(["state"])["price"].sum().sort_values(ascending=False).to_frame()

# %%
sns.set(rc={"figure.figsize" :(15,10)})
ax = sns.barplot(data=tc,x='state',y='price')
ax.tick_params(axis='x',rotation=90)

# %%
pd.value_counts(df['neighbourhood'])[:10].plot.bar()
plt.title("Top neighbourhoods with highest number of listings")
# Out:
# Text(0.5, 1.0, 'Top neighbourhoods with highest number of listings')

# %%
pd.value_counts(df['room_type'])[:10].plot.bar()
plt.title("Top  most prefered room type")
# Out:
# Text(0.5, 1.0, 'Top  most prefered room type')

# %%
avg_price_df = df.groupby(['state','room_type'])['price'].mean().unstack()
avg_price_df.plot.bar(figsize=(15,5),ylabel='Average Price calculated')
plt.title("Average price for each room_type according in each neighbourhood group")
# Out:
# Text(0.5, 1.0, 'Average price for each room_type according in each neighbourhood group')
